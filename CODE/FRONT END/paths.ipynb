# %%
import os 

paths = os.listdir('static\outputs')
for i in paths:
    print(r'static\outputs\{}'.format(i))
# Out:
# static\outputs\Dtc_con.png
# static\outputs\feature_imp.png
# static\outputs\logistic_con.png
# static\outputs\rf_con.png
# static\outputs\ROC and AUC for all models.png
# static\outputs\stack_con.png
